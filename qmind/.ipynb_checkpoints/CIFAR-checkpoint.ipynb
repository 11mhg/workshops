# %% [markdown]
# # QMIND Workshop
#
# In this workshop, we'll train and publish a CIFAR10 classifier to the Distributed Computer. This will allow us to submit a large number of tasks to a distributed computer to perform inference on a large number of images in parallel.
#
# Let's begin in python.

# %%
# %%capture
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt

# %%
try:
    import tensorflowjs as tfjs
except:
    # !pip install tensorflowjs tf-estimator-nightly 'ipykernel<5.0.0'
    import tensorflowjs as tfjs

# %%
(_xtrain, _ytrain), (_xtest, _ytest) = tf.keras.datasets.cifar10.load_data()
_xtrain = _xtrain.astype(np.float32) / 255.
_xtest  = _xtest.astype(np.float32)  / 255.

_ytrain_onehot = tf.keras.utils.to_categorical(_ytrain, 10)
_ytest_onehot  = tf.keras.utils.to_categorical(_ytest,  10)



print(_xtrain.min(), _xtrain.max(), _xtrain.dtype, _xtrain.shape, _ytest.shape)
# Out:
# 0.0 1.0 float32 (50000, 32, 32, 3) (10000, 1)

# %%
class Classifier(tf.keras.Model):
    def __init__(self, num_classes, name=None):
        super(Classifier, self).__init__(name=name)
        self.num_classes = num_classes
        
        self.ls = [
            tf.keras.layers.Conv2D(32 ,3,strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(64 ,3,strides=2, padding='same', activation='relu'),
            tf.keras.layers.Conv2D(128,3,strides=2, padding='same', activation='relu'),
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(512, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(self.num_classes, activation='softmax')
        ]
    
    @tf.function
    def call(self,x):
        for l in self.ls:
            x = l(x)
        return x

# %%
model = Classifier(10)

model.compile(
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
_history = model.fit(_xtrain, _ytrain_onehot,
         batch_size=128,
         verbose=1,
         epochs=10,
         callbacks=[
             tf.keras.callbacks.EarlyStopping(patience=3)
         ],
         validation_data=(_xtest, _ytest_onehot))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.9957 - accuracy: 0.2463 - val_loss: 1.7918 - val_accuracy: 0.3431
# Epoch 2/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.7422 - accuracy: 0.3581 - val_loss: 1.6202 - val_accuracy: 0.4093
# Epoch 3/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.5976 - accuracy: 0.4135 - val_loss: 1.5348 - val_accuracy: 0.4436
# Epoch 4/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.5020 - accuracy: 0.4481 - val_loss: 1.4258 - val_accuracy: 0.4755
# Epoch 5/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.4227 - accuracy: 0.4794 - val_loss: 1.4408 - val_accuracy: 0.4720
# Epoch 6/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.3547 - accuracy: 0.5049 - val_loss: 1.5868 - val_accuracy: 0.4334
# Epoch 7/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.2928 - accuracy: 0.5282 - val_loss: 1.2738 - val_accuracy: 0.5323
# Epoch 8/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.2387 - accuracy: 0.5523 - val_loss: 1.3555 - val_accuracy: 0.5003
# Epoch 9/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.1905 - accuracy: 0.5702 - val_loss: 1.2628 - val_accuracy: 0.5519
# Epoch 10/10
# 391/391 [==============================] - 5s 13ms/step - loss: 1.1493 - accuracy: 0.5828 - val_loss: 1.1878 - val_accuracy: 0.5775

# %%
plt.title("Loss")
plt.plot(_history.history['loss'])
plt.plot(_history.history['val_loss'])
plt.legend(['training loss', 'validation loss'])
plt.show()

plt.title("Acc")
plt.plot(_history.history['accuracy'])
plt.plot(_history.history['val_accuracy'])
plt.legend(['training accuracy', 'validation accuracy'])
plt.show()

# %% [markdown]
# # Publishing our model
#
# Now we'll clone this helpful tensorflowjs utility and use tensorflowjs converter to convert our python model to a tensorflowjs model and then publishing this model to the Distributed Computer.

# %%
# %%capture
# !git clone https://github.com/Kings-Distributed-Systems/tfjs_util.git
# !cd tfjs_util && npm i && npm run postinstall

# %%
# !mkdir -p './tfjs_model'
# !mkdir -p './saved_model'
model.save('./saved_model')
tfjs.converters.convert_tf_saved_model('./saved_model', './tfjs_model')
#Serialize and submit model to DCP package manager with version number X.X.XX 
# !node ./tfjs_util/bin/serializeModel.js -m ./tfjs_model/model.json \
    -o dcp_cifar_10_ex/cifar10.js -p 0.0.5 -d
# Out:
# Writing weight file ./tfjs_model/model.json...
# 2020-09-29 10:06:31.834174: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-09-29 10:06:31.862783: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2599990000 Hz
# 2020-09-29 10:06:31.863296: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x32f6520 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-29 10:06:31.863334: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Module published at :  dcp_cifar_10_ex/cifar10.js
# Done!

# %% [markdown]
# # Pixiedust-node
#
# Now we'll use a library that will enable us to run javascript in a jupyter notebook so that we can use the Distributed Compute Protocol to submit inference jobs to the cloud.

# %%
# %%capture
# !pip install pixiedust git+https://github.com/Kings-Distributed-Systems/pixiedust_node#egg=pixiedust_node

# %%
# %%capture
import pixiedust
import pixiedust_node

npm.install( ['dcp-client'] )
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>
# pixiedust_node 0.2.5 started. Cells starting '%%node' may contain Node.js code.
#             <div style="margin:10px">
#             <a href="https://github.com/pixiedust/pixiedust_node" target="_new">
#             <img src="https://github.com/pixiedust/pixiedust_node/raw/master/docs/_images/pdn_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust Node.js</span>
#             </div>
# /home/mgasmallah/.nvm/versions/node/v10.20.1/bin/npm install -s github:Kings-Distributed-Systems/npy-js
# + npy-js@1.0.0
# updated 1 package and audited 1370 packages in 3.584s
# 18 packages are looking for funding
# run `npm fund` for details
# found 29 vulnerabilities (13 low, 16 moderate)
# run `npm audit fix` to fix them, or `npm audit` for details
# /home/mgasmallah/.nvm/versions/node/v10.20.1/bin/npm install -s dcp-client
# + dcp-client@3.2.1
# updated 1 package and audited 1370 packages in 2.944s
# 18 packages are looking for funding
# run `npm fund` for details
# found 29 vulnerabilities (13 low, 16 moderate)
# run `npm audit fix` to fix them, or `npm audit` for details

# %%
ID_KEY_LOC = '/home/mgasmallah/DCP/keys/id.keystore'
ACC_KEY_LOC= '/home/mgasmallah/DCP/keys/AISTEST.keystore'
SCHEDULER  = 'https://demo-scheduler.distributed.computer'

node.clear();
# !job-utility cancelAllJobs -I $ID_KEY_LOC --default-bank-account-file $ACC_KEY_LOC --scheduler $SCHEDULER
# Out:
# Clearing context...
# Sending request cancelAllJobs...
# {
#   "description": "Cancelled 1 jobs.",
#   "stats": [
#     {
#       "id": "N4rGXIRFEDSn8h7MffSm9P",
#       "cancelStats": {
#         "job": {
#           "sort": 0,
#           "maxSlices": 100,
#           "resultsReceived": 0,
#           "previousRunStatus": "SLOWWORK"
#         },
#         "tasks": {
#           "canceled": 0
#         },
#         "miners": {
#           "canceled": 0
#         },
#         "heap": {
#           "jobsRemoved": 1,
#           "tasksRemoved": "none"
#         },
#         "escrow": {
#           "moved": "0.000000000000000000",
#           "returned": "0.014653760000000002"
#         }
#       }
#     }
#   ]
# }

# %%
# %%node
#
# process.argv.push('-I', ID_KEY_LOC, '--default-bank-account-file', ACC_KEY_LOC, '--scheduler', SCHEDULER)
# require('dcp-client').initSync(process.argv)
# const compute = require('dcp/compute');
# const wallet = require('dcp/wallet');
# const dcpCli = require('dcp/dcp-cli');
#
# var accountKeystore;
# var identityKeystore;
#
# (async function(){
#     identityKeystore = await dcpCli.getIdentityKeystore();
#     wallet.addId(identityKeystore);
#     accountKeystore = await dcpCli.getAccountKeystore();
#     console.log("Keystores loaded!");
# })();
# Out:
# ... ... ... ... ...
# Keystores loaded!

# %%
sample_cifar = _xtest[:100]
cifar_true   = _ytest_onehot[:100]

sample_cifar.shape, sample_cifar[0,0,0,0], cifar_true.shape, cifar_true.dtype
# Out:
# ((100, 32, 32, 3), 0.61960787, (100, 10), dtype('float32'))

# %%
# %%node
# var cifarResults = []
# async function main(){
#     let x = Float32Array.from(sample_cifar.typedArray);
#     let y = Float32Array.from(cifar_true.typedArray);
#
#     console.log(x[0]);
#
#     let submission_array = [];
#     let num_elem_x = sample_cifar.shape[1]*sample_cifar.shape[2]*sample_cifar.shape[3];
#     let num_elem_y = cifar_true.shape[1];
#     for (let i = 0; i < sample_cifar.shape[0]; i++){
#         submission_array.push(
#             {
#             'x': Array.from(x.slice(i*num_elem_x, (i+1) * num_elem_x)),
#             'y': Array.from(y.slice(i*num_elem_y, (i+1) * num_elem_y))
#             }
#         );
#     }
#
#     let job = compute.for( submission_array, async function(data){
#
#         progress(0.);
#         const tf = require('tfjs');
#         tf.setBackend('cpu');
#         await tf.ready();
#         progress(0.15);
#         const model = await require('cifar10').getModel();
#         progress(0.45);
#         let inpTensor = tf.tensor(data.x, [1, 32, 32, 3], dtype='float32');
#         let y_true    = tf.tensor(data.y, [1, 10], dtype='int32');
#         progress(0.5);
#         let y_pred = model.predict(inpTensor);
#         progress(0.75);
#         const accuracyTensor = tf.metrics.categoricalAccuracy(y_true, y_pred);
#         progress(0.85);
#         const acc = accuracyTensor.dataSync()[0];
#         progress(1.);
#         return acc;
#     });
#
#
#     job.on('accepted', ()=>{
#         console.log("Job Accepted...");
#     });
#
#      job.on('status', (status)=>{
#          console.log("Received a status update: ", status);
#      });
#     job.on('result', (value)=>{
#         cifarResults.push(value.result);
#
#     })
#     job.on('console', (output)=>{
#         console.log(output.message);
#     })
#     job.on('error', (err)=>{
#         console.log(err);
#     })
#
#     job.requires('aistensorflow/tfjs');
#     job.requires('dcp_cifar_10_ex/cifar10')
#
# //    job.requirements.environment.offscreenCanvas = true;
#     job.public.name = 'dcp-workshop';
#
#     await job.exec(compute.marketValue, accountKeystore);
#
#     console.log("Done Executing job!");
# }
#
# main();
# Out:
# ... ... ... ... ... ... ... ... ... ..... ....... ......... ......... ......... ....... ..... ... ... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ..... ... ... ... ..... ..... ... ... ..... ..... ... ..... ..... ..... ... ..... ..... ... ..... ..... ... ... ... ... ... ... ... ... ... ... ...
# 0.6196078658103943
#
# Job Accepted...
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 0, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 1, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 2, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 3, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 4, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 5, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 6, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 7, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 8, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK', total: 100, distributed: 9, computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 10,
# computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 11,
# computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 0 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 1 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 3 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 3 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 5 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 5 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 6 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 9 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 9 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 9 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 10 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 12,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 13,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 14,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 15,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 16,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 17,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 18,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 19,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 20,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 21,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 22,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 23,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 12 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 13 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 16 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 16 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 16 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 17 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 21 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 21 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 21 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 22 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 22 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 24,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 25,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 26,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 27,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 28,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 29,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 30,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 31,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 32,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 33,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 34,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 35,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 24 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 25 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 26 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 27 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 32 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 32 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 32 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 32 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 32 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 34 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 34 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 36,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 37,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 38,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 39,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 40,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 41,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 42,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 43,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 44,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 45,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 46,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 47,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 36 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 38 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 38 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 42 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 42 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 42 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 42 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 44 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 44 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 45 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 48,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 49,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 50,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 51,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 52,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 53,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 54,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 55,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 56,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 57,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 58,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 59,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 48 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 49 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 55 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 55 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 55 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 55 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 55 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 55 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 57 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 57 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 60,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 61,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 62,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 63,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 64,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 65,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 66,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 67,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 68,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 69,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 70,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 71,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 60 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 61 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 66 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 66 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 66 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 66 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 66 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 71 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 71 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 71 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 71 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 71 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 72,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 73,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 74,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 75,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 76,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 77,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 78,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 79,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 80,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 81,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 82,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 83,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 72 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 77 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 77 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 77 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 77 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 77 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 79 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 79 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 80 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 81 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 84,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 85,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 86,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 87,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 88,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 89,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 90,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 91,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 92,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 93,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 94,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 95,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 84 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 85 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 90 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 90 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 90 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 90 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 90 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 93 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 93 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 93 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 96 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 96 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 96,
# computed: 96 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 97,
# computed: 96 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 98,
# computed: 96 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 99,
# computed: 96 }
# Received a status update:  { runStatus: 'SLOWWORK',
# total: 100,
# distributed: 100,
# computed: 96 }
# Received a status update:  { runStatus: 'WAITING',
# total: 100,
# distributed: 100,
# computed: 99 }
# Received a status update:  { runStatus: 'WAITING',
# total: 100,
# distributed: 100,
# computed: 99 }
# Received a status update:  { runStatus: 'WAITING',
# total: 100,
# distributed: 100,
# computed: 99 }
# Received a status update:  { runStatus: 'WAITING',
# total: 100,
# distributed: 100,
# computed: 100 }
# Done Executing job!

# %%
print("Accuracy on distributed 100 set sample: ", sum(cifarResults)/len(cifarResults))
# Out:
# Accuracy on distributed 100 set sample:  0.63

# %% [markdown]
# # Your turn!
#
# Now try it with something like the fashion mnist dataset!

# %%
(_xtrain, _ytrain), (_xtest, _ytest) = tf.keras.datasets.fashion_mnist.load_data()


plt.imshow(_xtrain[np.random.randint(_xtrain.shape[0])], cmap='gray')
plt.show()
